# %%
tup1 = ('1','2')
tup2 = ('3','4')
lst1 = ['1','2']
lst2 = ['3','4']
lst3 = [lst1,lst2]
flat = lst1+lst2 #다른 것의 영향을 받지 않음
print('11: ',flat)
tuplst = [tup1, tup2]
print('1: ',lst3)
lst1.append('7')
tup3 = ('5','6')
tup1 = tup1 + tup3 #새 오브젝트를 만들음
print('2: ', tup1)
print('3: ',lst3)
print('12: ',flat)

# %%
def generateDictionary(n):
    dic = {}
    for i in range (n):
        word = input('프로그래밍 언어 이름: ')
        desc = input('프로그래밍 언어 설명: ')
        dic[word]=desc
    return dic

def printDictionary(*dicts): #*은 딕셔너리르 모으는 기능
    for dic in dicts:
        for word in dic:
            print(word, ':', dic[word])
    
n=int(input('Input number of programming language: '))
dic =  (generateDictionary(n))
new_dic = generateDictionary(n)
dic2 = {}
dic2['루비'] = '웹'
printDictionary (dic, new_dic,dic2)

# %%
def generateDictionary(n):
    dic = {}
    for i in range (n):
        word = input('프로그래밍 언어 이름: ')
        desc = input('프로그래밍 언어 설명: ')
        dic[word]=desc
    return dic

def translateDictionary(dic):
    new_dic = {}
    
    for word in dic:
        print("==========================")
        print('description:', dic[word])
        new_word = input('Input name of the language in Eng: ')
        new_dic[new_word] = dic[word]
    return new_dic
    
n=int(input('Input number of programming language: '))
dic =  (generateDictionary(n))
new_dic = translateDictionary(dic)
print(dic)
print(new_dic)

# %%
def generateDictionary(n):
    dic = {}
    for i in range (n):
        word = input('프로그래밍 언어 이름: ')
        desc = input('프로그래밍 언어 설명: ')
        dic[word]=desc
    return dic

def translateDictionary(dic):
    new_dic = {}
    
    for word in dic:
        print("===영어사전 생성===")
        print('description:', dic[word])
        new_word = input('Input name of the language in Eng: ')
        new_desc = input('Input description of the language in Eng: ')
        new_dic[new_word] = new_desc
    return new_dic
    
n=int(input('Input number of programming language: '))
dic =  (generateDictionary(n))
new_dic = translateDictionary(dic)
print(dic)
print(new_dic)

# %%
#설치 딕셔너리 만들어서 푸는 문제
#와일문이 필요함 본문 안에서 돌릴 수 있으면 돼,,,

# %%
def generateDictionary(n):
    dic = {}
    for i in range (n):
        word = input('프로그래밍 언어 이름: ')
        desc = input('프로그래밍 언어 설명: ')
        dic[word]=desc
    return dic

def translateDictionary(dic):
    new_dic = {}
    for word in dic:
        print("===영어사전 생성===")
        print('description:', dic[word])
        new_word = input('Input name of the language in Eng: ')
        new_desc = input('Input description of the language in Eng: ')
        new_dic[new_word] = new_desc
    return new_dic

def searchDictionary(*dicts):
    a = []
    while True:
        x = input('Enter a word for search: ')
        for i in dicts:
            for n in i:
                if x in i[n]:
                    a.append(n)
        if a == []:
            print ('No match!! Break!')
            break
        else:
            print(a)
        a = []
n=int(input('Input number of programming language: '))
dic =  (generateDictionary(n))
new_dic = translateDictionary(dic)
searchDictionary(dic, new_dic)
# Out:
# Input number of programming language: 2
# 프로그래밍 언어 이름: 파이썬
# 프로그래밍 언어 설명: 쉬운 프로그래밍 언어
# 프로그래밍 언어 이름: c언어
# 프로그래밍 언어 설명: 어려운 프로그래밍 언어
# ===영어사전 생성===
# description: 쉬운 프로그래밍 언어
# Input name of the language in Eng: Python
# Input description of the language in Eng: Easy programming language
# ===영어사전 생성===
# description: 어려운 프로그래밍 언어
# Input name of the language in Eng: C language
# Input description of the language in Eng: Hard programming language
# Enter a word for search: language
# ['Python', 'C language']
# Enter a word for search: 어려운
# ['c언어']
# Enter a word for search: 언어
# ['파이썬', 'c언어']
# Enter a word for search: 과제
# No match!! Break!

# %%
def generateDictionary(n):
    dic = {}
    for i in range (n):
        word = input('프로그래밍 언어 이름: ')
        desc = input('프로그래밍 언어 설명: ')
        dic[word]=desc
    return dic

def translateDictionary(dic):
    new_dic = {}
    for word in dic:
        print("===영어사전 생성===")
        print('description:', dic[word])
        new_word = input('Input name of the language in Eng: ')
        new_desc = input('Input description of the language in Eng: ')
        new_dic[new_word] = new_desc
    return new_dic

def searchDictionary(*dicts):
    a = []
    while True:
        x = input('Enter a word for search: ')
        for i in dicts:
            for n in i:
                if x in i[n]:
                    a.append(n)
        if a == []:
            print ('No match!! Break!')
            break
        else:
            print(a)
            
n=int(input('Input number of programming language: '))
dic =  (generateDictionary(n))
new_dic = translateDictionary(dic)
searchDictionary(dic, new_dic)
# Out:
# Input number of programming language: 2
# 프로그래밍 언어 이름: 파
# 프로그래밍 언어 설명: 쉬
# 프로그래밍 언어 이름: 씨
# 프로그래밍 언어 설명: 어
# ===영어사전 생성===
# description: 쉬
# Input name of the language in Eng: py
# Input description of the language in Eng: easy
# ===영어사전 생성===
# description: 어
# Input name of the language in Eng: c
# Input description of the language in Eng: hard
# Enter a word for search: hard
# ['c']
# Enter a word for search: easy
# ['c', 'py']
# Enter a word for search: 쉬
# ['c', 'py', '파']
# Enter a word for search: 2
# ['c', 'py', '파']
# Enter a word for search: ㅇ
# ['c', 'py', '파']
# Enter a word for search: 9
# ['c', 'py', '파']
# Enter a word for search: 5
# ['c', 'py', '파']
# Enter a word for search: 6'
# ['c', 'py', '파']

# %%
x = {'1':'ㄱ','2':'ㄴ','3':'ㄷ','4':'ㄹ','5':'ㅁ','6':'ㅇ'}
y = {'가':'a','나':'b','다':'c','라':'d'}
def f(*dicts):
    for i in dicts:
        print('i: ',i)
        for n in i:
            print('n: ',n)
            print('이해x: ', i[n])
        
f(x,y)
# Out:
# i:  {'1': 'ㄱ', '2': 'ㄴ', '3': 'ㄷ', '4': 'ㄹ', '5': 'ㅁ', '6': 'ㅇ'}
# n:  1
# 이해x:  ㄱ
# n:  2
# 이해x:  ㄴ
# n:  3
# 이해x:  ㄷ
# n:  4
# 이해x:  ㄹ
# n:  5
# 이해x:  ㅁ
# n:  6
# 이해x:  ㅇ
# i:  {'가': 'a', '나': 'b', '다': 'c', '라': 'd'}
# n:  가
# 이해x:  a
# n:  나
# 이해x:  b
# n:  다
# 이해x:  c
# n:  라
# 이해x:  d
